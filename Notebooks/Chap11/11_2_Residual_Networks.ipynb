# %% [markdown]
# <a href="https://colab.research.google.com/github/R245-tech/docs/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-f39luk_s
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-f39luk_s
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=d6ab492b139e3199ac48fe10747e62b699a1d187c37fc27a0f551c82c81d5b8d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_ydx1q8q/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    #linear 1
    h1 = self.linear1(x)

    #linear 2
    h1_relu= h1.relu()
    h2 = self.linear2(h1_relu)
    h2_res = h1+h2

    #lineaar 3
    h2_relu = h2_res.relu()
    h3 = self.linear3(h2_relu)
    h3_res = h2_res+h3

    #linear 4
    return self.linear4(h3_res)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.713984, train error 63.97,  val loss 1.779723, percent error 66.80
# Epoch     1, train loss 1.170401, train error 44.70,  val loss 1.360026, percent error 54.40
# Epoch     2, train loss 1.045479, train error 39.03,  val loss 1.224938, percent error 47.40
# Epoch     3, train loss 0.941667, train error 36.28,  val loss 1.208776, percent error 43.90
# Epoch     4, train loss 0.763802, train error 29.07,  val loss 1.099020, percent error 43.20
# Epoch     5, train loss 0.751784, train error 29.78,  val loss 1.191160, percent error 44.50
# Epoch     6, train loss 0.670911, train error 25.95,  val loss 1.161296, percent error 41.10
# Epoch     7, train loss 0.599355, train error 22.07,  val loss 1.184219, percent error 42.20
# Epoch     8, train loss 0.604222, train error 22.80,  val loss 1.266203, percent error 41.80
# Epoch     9, train loss 0.534510, train error 19.95,  val loss 1.236592, percent error 40.20
# Epoch    10, train loss 0.462791, train error 17.88,  val loss 1.223719, percent error 36.30
# Epoch    11, train loss 0.424757, train error 15.22,  val loss 1.232678, percent error 38.10
# Epoch    12, train loss 0.367024, train error 13.97,  val loss 1.266132, percent error 35.90
# Epoch    13, train loss 0.345078, train error 12.32,  val loss 1.293132, percent error 35.70
# Epoch    14, train loss 0.244864, train error 8.50,  val loss 1.365057, percent error 35.00
# Epoch    15, train loss 0.354478, train error 13.15,  val loss 1.443499, percent error 36.40
# Epoch    16, train loss 0.312158, train error 11.55,  val loss 1.534918, percent error 37.40
# Epoch    17, train loss 0.349287, train error 12.78,  val loss 1.578430, percent error 37.00
# Epoch    18, train loss 0.395353, train error 13.90,  val loss 1.723043, percent error 37.90
# Epoch    19, train loss 0.374108, train error 12.82,  val loss 1.705903, percent error 37.70
# Epoch    20, train loss 0.104324, train error 3.05,  val loss 1.337357, percent error 32.80
# Epoch    21, train loss 0.067353, train error 1.97,  val loss 1.378434, percent error 31.70
# Epoch    22, train loss 0.028530, train error 0.22,  val loss 1.363824, percent error 32.00
# Epoch    23, train loss 0.018553, train error 0.05,  val loss 1.361595, percent error 30.70
# Epoch    24, train loss 0.013779, train error 0.00,  val loss 1.393642, percent error 31.50
# Epoch    25, train loss 0.011456, train error 0.00,  val loss 1.431765, percent error 31.20
# Epoch    26, train loss 0.009646, train error 0.00,  val loss 1.445437, percent error 30.90
# Epoch    27, train loss 0.008402, train error 0.00,  val loss 1.474653, percent error 30.70
# Epoch    28, train loss 0.007469, train error 0.00,  val loss 1.498022, percent error 30.30
# Epoch    29, train loss 0.006737, train error 0.00,  val loss 1.517562, percent error 30.30
# Epoch    30, train loss 0.006124, train error 0.00,  val loss 1.536441, percent error 30.40
# Epoch    31, train loss 0.005627, train error 0.00,  val loss 1.550231, percent error 30.30
# Epoch    32, train loss 0.005268, train error 0.00,  val loss 1.569186, percent error 30.10
# Epoch    33, train loss 0.004850, train error 0.00,  val loss 1.583401, percent error 30.10
# Epoch    34, train loss 0.004511, train error 0.00,  val loss 1.593936, percent error 30.00
# Epoch    35, train loss 0.004227, train error 0.00,  val loss 1.611032, percent error 30.20
# Epoch    36, train loss 0.003978, train error 0.00,  val loss 1.621857, percent error 30.20
# Epoch    37, train loss 0.003757, train error 0.00,  val loss 1.633120, percent error 30.20
# Epoch    38, train loss 0.003563, train error 0.00,  val loss 1.646793, percent error 30.10
# Epoch    39, train loss 0.003379, train error 0.00,  val loss 1.655808, percent error 30.10
# Epoch    40, train loss 0.003292, train error 0.00,  val loss 1.661911, percent error 30.30
# Epoch    41, train loss 0.003214, train error 0.00,  val loss 1.666727, percent error 30.40
# Epoch    42, train loss 0.003140, train error 0.00,  val loss 1.671098, percent error 30.40
# Epoch    43, train loss 0.003068, train error 0.00,  val loss 1.677194, percent error 30.50
# Epoch    44, train loss 0.003001, train error 0.00,  val loss 1.681347, percent error 30.60
# Epoch    45, train loss 0.002935, train error 0.00,  val loss 1.685397, percent error 30.40
# Epoch    46, train loss 0.002873, train error 0.00,  val loss 1.691300, percent error 30.60
# Epoch    47, train loss 0.002812, train error 0.00,  val loss 1.696056, percent error 30.50
# Epoch    48, train loss 0.002755, train error 0.00,  val loss 1.698943, percent error 30.30
# Epoch    49, train loss 0.002699, train error 0.00,  val loss 1.704175, percent error 30.40
# Epoch    50, train loss 0.002646, train error 0.00,  val loss 1.708812, percent error 30.30
# Epoch    51, train loss 0.002594, train error 0.00,  val loss 1.713044, percent error 30.40
# Epoch    52, train loss 0.002544, train error 0.00,  val loss 1.717177, percent error 30.50
# Epoch    53, train loss 0.002496, train error 0.00,  val loss 1.721443, percent error 30.50
# Epoch    54, train loss 0.002449, train error 0.00,  val loss 1.724842, percent error 30.40
# Epoch    55, train loss 0.002405, train error 0.00,  val loss 1.729921, percent error 30.40
# Epoch    56, train loss 0.002361, train error 0.00,  val loss 1.732852, percent error 30.40
# Epoch    57, train loss 0.002321, train error 0.00,  val loss 1.736972, percent error 30.50
# Epoch    58, train loss 0.002280, train error 0.00,  val loss 1.741048, percent error 30.70
# Epoch    59, train loss 0.002241, train error 0.00,  val loss 1.745047, percent error 30.50
# Epoch    60, train loss 0.002221, train error 0.00,  val loss 1.746593, percent error 30.60
# Epoch    61, train loss 0.002202, train error 0.00,  val loss 1.748507, percent error 30.60
# Epoch    62, train loss 0.002184, train error 0.00,  val loss 1.750275, percent error 30.60
# Epoch    63, train loss 0.002166, train error 0.00,  val loss 1.752225, percent error 30.60
# Epoch    64, train loss 0.002148, train error 0.00,  val loss 1.754121, percent error 30.60
# Epoch    65, train loss 0.002130, train error 0.00,  val loss 1.755666, percent error 30.60
# Epoch    66, train loss 0.002113, train error 0.00,  val loss 1.757135, percent error 30.50
# Epoch    67, train loss 0.002096, train error 0.00,  val loss 1.759135, percent error 30.60
# Epoch    68, train loss 0.002079, train error 0.00,  val loss 1.760990, percent error 30.40
# Epoch    69, train loss 0.002063, train error 0.00,  val loss 1.762251, percent error 30.60
# Epoch    70, train loss 0.002046, train error 0.00,  val loss 1.764517, percent error 30.50
# Epoch    71, train loss 0.002031, train error 0.00,  val loss 1.765843, percent error 30.50
# Epoch    72, train loss 0.002015, train error 0.00,  val loss 1.767430, percent error 30.60
# Epoch    73, train loss 0.001999, train error 0.00,  val loss 1.769465, percent error 30.40
# Epoch    74, train loss 0.001984, train error 0.00,  val loss 1.770791, percent error 30.60
# Epoch    75, train loss 0.001969, train error 0.00,  val loss 1.772748, percent error 30.40
# Epoch    76, train loss 0.001954, train error 0.00,  val loss 1.774358, percent error 30.50
# Epoch    77, train loss 0.001939, train error 0.00,  val loss 1.775704, percent error 30.60
# Epoch    78, train loss 0.001925, train error 0.00,  val loss 1.777466, percent error 30.50
# Epoch    79, train loss 0.001911, train error 0.00,  val loss 1.779131, percent error 30.50
# Epoch    80, train loss 0.001904, train error 0.00,  val loss 1.779834, percent error 30.50
# Epoch    81, train loss 0.001897, train error 0.00,  val loss 1.780492, percent error 30.50
# Epoch    82, train loss 0.001890, train error 0.00,  val loss 1.781569, percent error 30.50
# Epoch    83, train loss 0.001883, train error 0.00,  val loss 1.782222, percent error 30.50
# Epoch    84, train loss 0.001876, train error 0.00,  val loss 1.783102, percent error 30.60
# Epoch    85, train loss 0.001869, train error 0.00,  val loss 1.783945, percent error 30.50
# Epoch    86, train loss 0.001862, train error 0.00,  val loss 1.784653, percent error 30.60
# Epoch    87, train loss 0.001856, train error 0.00,  val loss 1.785650, percent error 30.70
# Epoch    88, train loss 0.001849, train error 0.00,  val loss 1.786107, percent error 30.50
# Epoch    89, train loss 0.001842, train error 0.00,  val loss 1.786813, percent error 30.60
# Epoch    90, train loss 0.001836, train error 0.00,  val loss 1.787769, percent error 30.60
# Epoch    91, train loss 0.001829, train error 0.00,  val loss 1.788415, percent error 30.60
# Epoch    92, train loss 0.001823, train error 0.00,  val loss 1.789294, percent error 30.50
# Epoch    93, train loss 0.001816, train error 0.00,  val loss 1.790252, percent error 30.60
# Epoch    94, train loss 0.001810, train error 0.00,  val loss 1.790844, percent error 30.60
# Epoch    95, train loss 0.001804, train error 0.00,  val loss 1.791517, percent error 30.50
# Epoch    96, train loss 0.001797, train error 0.00,  val loss 1.792315, percent error 30.60
# Epoch    97, train loss 0.001791, train error 0.00,  val loss 1.793081, percent error 30.60
# Epoch    98, train loss 0.001785, train error 0.00,  val loss 1.793859, percent error 30.60
# Epoch    99, train loss 0.001779, train error 0.00,  val loss 1.794361, percent error 30.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
